# %%
import numpy as np
import time

# %%
z1 = time.time()
liste = []
for a in range(1000000):
    kuvvet = a**100
    liste.append(kuvvet)
z2 = time.time()
print(z2-z1)
# Out:
# 1.9410302639007568

# %%
z3 = time.time()
liste2=np.arange(1000000)**100
z4 = time.time()
print(z4-z3)
# Out:
# 0.009993553161621094
